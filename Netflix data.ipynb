# %%
# (1) importing python libraries
import pandas as pd
import numpy as np

# %%
#(2) Assigning variable and reading of dataframe
sm = pd.read_csv('Copy of Netflix_data.csv')

# %%
sm
# Out:
#                                              Title        Date
# 0                                 Almost Christmas  24/12/2024
# 1                                Our Little Secret  18/12/2024
# 2                   Twas the Text Before Christmas  18/12/2024
# 3    My Demon: Limited Series: Our Personal Heaven  10/12/2024
# 4        My Demon: Limited Series: The End of Fate  10/12/2024
# ..                                             ...         ...
# 110        All of Us Are Dead: Season 1: Episode 2  08/03/2024
# 111        All of Us Are Dead: Season 1: Episode 1  08/03/2024
# 112               Zom 100: Bucket List of the Dead  08/03/2024
# 113           Happiness: Limited Series: Episode 1  08/03/2024
# 114                Avatar The Last Airbender: Aang  07/03/2024
#
# [115 rows x 2 columns]

# %%
#(3) Checking of top 10 rows using sm.head() function
sm.head(10)
# Out:
#                                                Title        Date
# 0                                   Almost Christmas  24/12/2024
# 1                                  Our Little Secret  18/12/2024
# 2                     Twas the Text Before Christmas  18/12/2024
# 3      My Demon: Limited Series: Our Personal Heaven  10/12/2024
# 4          My Demon: Limited Series: The End of Fate  10/12/2024
# 5        My Demon: Limited Series: Our Personal Hell  10/12/2024
# 6  My Demon: Limited Series: The Past, the Origin...  09/12/2024
# 7  My Demon: Limited Series: The Savior of Destru...  09/12/2024
# 8  My Demon: Limited Series: A Paradise of the Om...  08/12/2024
# 9  My Demon: Limited Series: Breaking Through the...  08/12/2024

# %%
#(4) Number of rows and columns of the dataset
sm.shape
# Out:
# (115, 2)

# %%
#(4i) Number of rows in the dataset
sm.shape[0]
# Out:
# 115

# %%
#(4ii) Number of columns in the dataset
sm.shape[1]
# Out:
# 2

# %%
#(5) Description pf the dataset
sm.describe()
# Out:
#                    Title        Date
# count                115         115
# unique               115          48
# top     Almost Christmas  21/07/2024
# freq                   1          13

# %% [markdown]
# The .describe() function gives a statistics description of the data.It indicates the statistical frequency which shows the number of times a data apppears in the dataset.

# %%
# using the .isna() function
sm.isna()
# Out:
#      Title   Date
# 0    False  False
# 1    False  False
# 2    False  False
# 3    False  False
# 4    False  False
# ..     ...    ...
# 110  False  False
# 111  False  False
# 112  False  False
# 113  False  False
# 114  False  False
#
# [115 rows x 2 columns]

# %%
# using the lambda function
# The union
sm['Title'].apply(lambda title: 'The Union' in title).sum()
# Out:
# 1

# %%
sm['Title'].apply(lambda title: 'The Master Of The House' in title).sum()
# Out:
# 0

# %%
sm['Title'].apply(lambda title: 'My Name' in title).sum()
# Out:
# 8

# %%
sm['Title'].apply(lambda title: 'Postcards' in title).sum()
# Out:
# 6
